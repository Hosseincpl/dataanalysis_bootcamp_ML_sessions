# %% [markdown]
# <h1 align=center style="line-height:200%;font-family:vazir;color:#0099cc">
# <font face="vazir" color="#0099cc">
# کِی
# </font>
# </h1>

# %% [markdown]
# <h2 align=right style="line-height:200%;font-family:vazir;color:#0099cc">
# <font face="vazir" color="#0099cc">
# مقدمه و صورت مسئله
# </font>
# </h2>
#
# <p dir=rtl style="direction: rtl; text-align: justify; line-height:200%; font-family:vazir; font-size:medium">
# <font face="vazir" size=3>
#     مسافران به دلایل مختلفی بلیط رزرو میکنند و ممکن است به دلایل دیگر آن ها را لغو کنند. شرکتی مانند مستربلیط که بلیط‌های اتوبوس، هواپیما و ... ارائه می‌کند با تعداد آژانس مسافربری مانند رویال سفر و هما قرارداد بسته و به ازای هر بلیطی که بفروشد، مبلغی را تحت عنوان کمسیون، سود میکند!
#     <br>
#     اما در مقابل، هنگامی که مسافران بلیط خود را کنسل می‌کنند، مستربلیط باید مبلغی را تحت عنوان جریمه به آژانس‌های مسافربری بپردازد. از آن‌جایی که سیاست مستربلیط بر این است که بخشی از جریمه را از خود مسافر بستاند، بنابراین از شما می‌خواهد پیش‌بینی کنید که کِی، یک مسافر بلیط خود را لغو میکند.
#     <br>
#     قیمت‌گذاری مستربلیط برای جریمه مسافران به این شکل است :
#     <br>
#     بلیط تا 1 ساعت بعد از صدور (چنانچه بیشتر از 2 ساعت به حرکت مانده باشد) بدون جریمه، تا 1 ساعت قبل از حرکت با 10% جریمه و پس از آن با 50% جریمه به صورت اینترنتی قابل کنسل می باشد.
#
# </font>
# </p>

# %% [markdown]
# <h2 align=right style="line-height:200%;font-family:vazir;color:#0099cc">
# <font face="vazir" color="#0099cc">
# وارد کردن کتابخانه‌های مورد نیاز
# </font>
# </h2>
#
# <p dir=rtl style="direction: rtl; text-align: justify; line-height:200%; font-family:vazir; font-size:medium">
# <font face="vazir" size=3>
#     ابتدا کتابخانه‌های مورد نیازتان را وارد کنید.
# </font>
# </p>

# %%
import warnings
warnings.filterwarnings("ignore")

import pandas as pd
import numpy as np 
from pandas_profiling import ProfileReport

from sklearn.preprocessing import LabelEncoder
from imblearn.over_sampling import SMOTENC
from flaml import AutoML

# %% [markdown]
# <h2 align=right style="line-height:200%;font-family:vazir;color:#0099cc">
# <font face="vazir" color="#0099cc">
# معرفی مجموعه داده
# </font>
# </h2>
#
# <p dir=rtl style="direction: rtl; text-align: justify; line-height:200%; font-family:vazir; font-size:medium">
# <font face="vazir" size=3>
#     مجموعه داده آموزشی که در فایل <code>train_data.csv</code> قرار دارد، شامل ۱۳۵۰۰ سطر است که در جدول زیر، توضیحات هر ستون آمده است.
# </font>
# </p>
#
# <center>
# <div dir=rtl style="direction: rtl;line-height:200%;font-family:vazir;font-size:medium">
# <font face="vazir" size=3>
#
# |ستون|توضیحات|
# |:------:|:---:|
# |Created|زمان ثبت بلیط|
# |DepartureTime|زمان حرکت|
# |BillID|شناسه خرید|
# |TicketID|شناسه بلیط|
# |ReserveStatus|وضعیت رزرواسیون مشتری که به دلایلی از سمت مستربلیط، معنی اعداد این ستون روشن نشده است!|
# |UserID|شناسه کاربری|
# |Male|آیا بلیط متعلق به زن است یا مرد|
# |Price|قیمت بلیط بدون تخفیف|
# |CouponDiscount|تخفیفی که شخص روی بلیط اعمال کرده است|
# |From|مبدا سفر|
# |To|مقصد سفر|
# |Domestic|آیا سفر، داخلی است یا خارجی|
# |VehicleType|جزئیات وسیله نقلیه را مشخص می‌کند|
# |VehicleClass|آیا وسیله نقلیه، فرست‌کلس است یا نه|
# |TripReason|دلیل سفر (کاری و غیر کاری)|
# |Vehicle|نوع وسیله نقلیه|
# |HashPassportNumber_p|هش‌شده شماره پاسپورت|
# |HashEmail|هش‌شده ایمیل|
# |BuyerMobile|هش‌شده شماره موبایل|
# |NationalCode|هش‌شده شماره‌ملی|
# |target|درصدی که مسافر باید جریمه بپردازد (ستون هدف)|
# </font>
# </div>
# </center>
#
# <br>
# <br>
#
#
# <p dir=rtl style="direction: rtl; text-align: justify; line-height:200%; font-family:vazir; font-size:medium">
# <font face="vazir" size=3>
#     در کنار مجموعه داده آموزش، مجموعه دیگری از اطلاعات کاربران مستربلیط به ما داده شده است که توضیحات آن را در جدول زیر مشاهده می‌کنیم.
# </font>
# </p>
#
#
# <center>
# <div dir=rtl style="direction: rtl;line-height:200%;font-family:vazir;font-size:medium">
# <font face="vazir" size=3>
#
# |ستون|توضیحات|
# |:------:|:---:|
# |BuyerMobile|هش‌شده شماره موبایل|
# |PreferedServiceMap|نام نوع سرویس یا خدمت ارجح‌ داده‌شده توسط کاربر|
# |BuyingInterval|میانگین فاصله بین خریدهای کاربر بر اساس روز (درصورتی که یک خرید بیشتر نباشد عدد 0)|
# |FrequencyStage|تعداد خریدهای کاربر|
# |From|پرتکرارترین مبدا ثبت‌شده در خریدهای کاربر|
#
# </font>
# </div>
# </center>
#
#
#
# <p dir=rtl style="direction: rtl; text-align: justify; line-height:200%; font-family:vazir; font-size:medium">
# <font face="vazir" size=3>
#     در استفاده از داده‌ها، به این نکات توجه داشته باشید:
#     <ul dir=rtl style="direction: rtl; text-align: justify;">
#         <li>مسافران با استفاده هش شماره موبایل‌شان از یکدیگر تفکیک می شوند. بنابراین از ستون <code>BuyerMobile</code> میتوانید برای اتصال دو مجموعه داده استفاده کنید.</li>
#         <li>در هر خرید، مسافر می‌تواند بیشتر از ۱ بلیط خریداری کند. بنابراین با یک <code>BillID</code> ممکن است بیش از یک <code>TicketID</code> دیده شود!</li>
#     </ul>
# </font>
# </p>

# %%
df = pd.read_csv('data/train_data.csv')

# %%
df
# Out:
#                        Created            DepartureTime    BillID  ...   BuyerMobile  NationalCode  target
# 0      2022-03-31 18:02:23.787  2022-04-03 21:00:00.000  36747369  ...  396856962642     946582672     10%
# 1      2022-05-17 22:05:09.693  2022-05-26 17:00:00.000  37370235  ...  263373860744     264039157    free
# 2      2022-08-29 21:36:16.417  2022-09-06 15:55:00.000  38911942  ...  836531213515      40307748    free
# 3      2022-02-27 07:16:27.157  2022-03-19 15:20:00.000  36198455  ...  996258900076       1112341     10%
# 4      2022-07-23 14:37:30.550  2022-08-08 19:30:00.000  38387519  ...  601992127142     725979974     10%
# ...                        ...                      ...       ...  ...           ...           ...     ...
# 13495  2022-01-08 08:17:17.043  2022-01-12 15:45:00.000  35623875  ...  681500278543     862270585     10%
# 13496  2022-09-24 10:01:19.490  2022-10-01 08:30:00.000  39308700  ...  365907584807     339537531     10%
# 13497  2022-02-19 10:37:46.267  2022-02-25 10:33:00.000  36117220  ...  396110241704     337405956    free
# 13498  2022-09-09 14:23:32.827  2022-09-20 21:55:00.000  39082277  ...   75744190023     362894914    free
# 13499  2022-01-30 20:53:52.250  2022-02-08 10:15:00.000  35897721  ...  778860092103     339788739    free
#
# [13500 rows x 21 columns]

# %% [markdown]
# <h2 align=right style="line-height:200%;font-family:vazir;color:#0099cc">
# <font face="vazir" color="#0099cc">
# پیش‌پردازش و مهندسی ویژگی
# </font>
# </h2>
#
# <p dir=rtl style="direction: rtl; text-align: justify; line-height:200%; font-family:vazir; font-size:medium">
# <font face="vazir" size=3>
#     در این سوال شما می‌توانید از هر تکنیک پیش‌پردازش/مهندسی ویژگی که در فصل‌های گذشته آموختید، استفاده کنید.
#     <br>
#     تکنیک‌هایی که استفاده می‌کنید به شکل مستقیم مورد ارزیابی توسط سامانه داوری قرار <b>نمی‌گیرند.</b> بلکه همه آن‌ها در دقت مدل شما تاثیر خواهند گذاشت؛ بنابراین هر چه پیش‌پردازش/مهندسی ویژگی بهتری انجام دهید تا دقت مدل بهبود پیدا کند، امتیاز بیشتری از این سوال کسب خواهید کرد.
# </font>
# </p>

# %%
from sklearn.model_selection import train_test_split

train , test = train_test_split(df, test_size=.2, random_state=313)

# %%
class Preprocessor : 
    def __init__ (self)  : 
        pass 
    
    
    def to_datetime(self, data) : 
        data[['Created', 'DepartureTime']] = data[['Created', 'DepartureTime']].apply(pd.to_datetime)             
        return data
    
    
    def merge(self, data, path='../data/UserFeatures.csv', prev_on = 'BuyerMobile', new_on = 'BuyerMobile') :
        users = pd.read_csv(path)
        data = pd.merge(data,users, left_on='BuyerMobile', right_on='BuyerMobile')
        return data
    
    def drop_cols(self, data, useless_cols ) :
        return data.drop(useless_cols, axis=1)
        
        
    def replace (self, data, col, value) :
        data[col].replace(value, inplace=True)        
        return data
    
    def fillna(self, data, col, value) :
        data[col].fillna(value, inplace=True)
        return data
    
        
    def count_each_target_group (self, group) : 
        normalization_factor = len(group) + 1
        return group.BuyerMobile.values[0], \
                (len(group[group.target=='10%']) + 1)/normalization_factor  ,\
                (len(group[group.target=='50%']) + 1)/normalization_factor  ,\
                (len(group[group.target=='free']) + 1)/normalization_factor
    
    def extract_user_activity_history(self, data) :
        frequent_cancel_type = pd.DataFrame.from_records(
                                data.groupby('BuyerMobile').apply(self.count_each_target_group).values,
                                columns = ['BuyerMobile', '10%', '50%', 'free'])

        data = pd.merge(data,frequent_cancel_type, left_on='BuyerMobile', right_on = 'BuyerMobile')
        return data
    
    def is_family (self, rows) : 
        return (True in rows.values) and (False in rows.values)    
    
    
    def encode_cities(self, data) :
        cities = data.From.append(data.To).values
        city_encoder = LabelEncoder().fit(cities)
        self.city2idx = dict(zip(city_encoder.classes_, city_encoder.transform(city_encoder.classes_)))
        self.city2idx['iran'] = -1 
            

    def transform_cities(self, data, col) : 
        try : 
            data[col] = data[col].map(self.city2idx).fillna(self.city2idx['iran']).astype(int)
            return data
        
        except KeyError as exc:  
            print(exc)
            raise Exception('Something went wrong. Maybe this class is used for test data before fit on train data!')
            
    def encode_bool_cols (self, data) : 
        bool_cols = data.select_dtypes('bool').columns
        for col in bool_cols : 
            data[col].replace({True:1, False:0}, inplace=True,)
            
        return data
    
    def encode_vehicle(self, data) :
        vehicles = data.Vehicle.values
        vehcile_encoder = LabelEncoder().fit(vehicles)
        self.vehicle2idx = dict(zip(vehcile_encoder.classes_, vehcile_encoder.transform(vehcile_encoder.classes_)))
        
    def transform_vehicle(self, data) : 
        try : 
            data['Vehicle'] = data.Vehicle.map(self.vehicle2idx).fillna(self.vehicle2idx['Bus']).astype(int)
            return data
        
        except KeyError as exc:  
            raise Exception('Something went wrong. Maybe this class is used for test data before fit on train data!')
          
        
    
    def transform(self, df, is_train) : 
        data = self.to_datetime(df) 
        
        
        data = self.merge(data, 'data/UserFeatures.csv', prev_on = 'BuyerMobile', new_on = 'BuyerMobile') 
        
        
        data = self.drop_cols(data, useless_cols = ['UserID', 'HashPassportNumber_p', 'HashEmail', 'NationalCode', \
                'VehicleType', 'VehicleClass', 'TripReason'])
        
        
        data = self.replace(data, col= 'Vehicle', value = {'InternationalPlane' : 'Plane'} )
        
        
        data = self.fillna(data, col = 'Male', value = data.Male.mode().values[0])  
        data = self.fillna(data, col = 'From_y', value = 'iran')  
        data = self.fillna(data, col = 'To', value = 'iran')  
        
        
        data = self.extract_user_activity_history(data)
        
        
        data['has_used_different_service'] = data.Vehicle != data.PreferedServiceMap
        data['travelling_from_different_origin'] = data.From_x != data.From_y
        
        
        data['TimeDiff'] = (data['DepartureTime'] - data['Created']).dt.days
        data['TicketPerOrder'] = data.groupby('BillID').TicketID.transform('count')

        
        data['is_with_familiy'] = data.groupby('BillID').Male.transform(self.is_family)

        data['net_price'] = data.Price - data.CouponDiscount
        data['net_price'] /= data['net_price'].max()
        data['has_discount'] = data.CouponDiscount > 0
        
        
        usefull_cols = ['Male', 'ReserveStatus', 'From_x', 'To', 'Domestic', 'Vehicle', 'BuyingInterval', 'FrequencyStage',\
               'has_used_different_service', 'travelling_from_different_origin', 'TimeDiff', 'TicketPerOrder', \
               'is_with_familiy', 'net_price', 'has_discount', 'target']
        data = data[usefull_cols]
        
        
        data.rename({'From_x' : 'From'}, axis=1, inplace=True)
        
        if is_train : 
            self.encode_cities(data)
        data = self.transform_cities(data, col='From')
        data = self.transform_cities(data, col='To')
        
        
        data = self.encode_bool_cols(data) 
        
        
        if is_train : 
            self.encode_vehicle(data) 
        data = self.transform_vehicle(data)
        
        return data

# %%
p = Preprocessor() 
ctrain = train.copy()
ctrain = p.transform(ctrain,is_train=True)

# %%
ctest ‍= test.copy()
ctest = p.transform(ctest, is_train=False)
# Out:
#   Cell In[8], line 1
#     ctest ‍= test.copy()
#           ^
# SyntaxError: invalid character in identifier

# %%
ctrain
# Out:
#       Male  ReserveStatus  From   To  Domestic  ...  TicketPerOrder  is_with_familiy  net_price  has_discount  target
# 0        1              5    89  126         1  ...               1                0   0.002254             0     10%
# 1        0              4    65  161         1  ...               2                0   0.001514             0     10%
# 2        0              4    65  161         1  ...               2                0   0.001514             0     10%
# 3        0              5   161   63         1  ...               1                0   0.022973             0     10%
# 4        1              5    34   63         1  ...               1                0   0.002430             1     10%
# ...    ...            ...   ...  ...       ...  ...             ...              ...        ...           ...     ...
# 7053     1              4   161   63         1  ...               1                0   0.004605             0     10%
# 7054     1              5    97   28         1  ...               1                0   0.023893             0     10%
# 7055     1              4   146   63         1  ...               1                0   0.000158             0    free
# 7056     1              4    63  161         1  ...               1                0   0.015425             0     10%
# 7057     0              5   104   28         1  ...               1                0   0.023724             0     10%
#
# [7058 rows x 16 columns]

# %%
ctrain.isna().sum().sum()
# Out:
# 0

# %%
ctest
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 ctest
#
# NameError: name 'ctest' is not defined

# %%
ctest.isna().sum().sum()
# Out:
# 0

# %%
ctrain
# Out:
#       Male  ReserveStatus  From   To  Domestic  ...  TicketPerOrder  is_with_familiy  net_price  has_discount  target
# 0        1              5    89  126         1  ...               1                0   0.002254             0     10%
# 1        0              4    65  161         1  ...               2                0   0.001514             0     10%
# 2        0              4    65  161         1  ...               2                0   0.001514             0     10%
# 3        0              5   161   63         1  ...               1                0   0.022973             0     10%
# 4        1              5    34   63         1  ...               1                0   0.002430             1     10%
# ...    ...            ...   ...  ...       ...  ...             ...              ...        ...           ...     ...
# 7053     1              4   161   63         1  ...               1                0   0.004605             0     10%
# 7054     1              5    97   28         1  ...               1                0   0.023893             0     10%
# 7055     1              4   146   63         1  ...               1                0   0.000158             0    free
# 7056     1              4    63  161         1  ...               1                0   0.015425             0     10%
# 7057     0              5   104   28         1  ...               1                0   0.023724             0     10%
#
# [7058 rows x 16 columns]

# %%
import seaborn as sns
ctrain.target.value_counts()
# Out:
# 10%     5811
# free    1146
# 50%      101
# Name: target, dtype: int64

# %%
continuous_cols = ['BuyingInterval', 'FrequencyStage', 'TimeDiff', 'TicketPerOrder', 'net_price']
cat_cols = set(ctrain.columns).symmetric_difference(set(continuous_cols))
cat_cols = list(cat_cols)
cat_cols.remove('target')
cat_cols
# Out:
# ['Domestic',
#  'To',
#  'From',
#  'is_with_familiy',
#  'travelling_from_different_origin',
#  'has_used_different_service',
#  'has_discount',
#  'Male',
#  'Vehicle',
#  'ReserveStatus']

# %%
cat_cols = [ctrain.columns.get_loc(c) for c in cat_cols if c in ctrain]

# %%
oversample = SMOTENC(categorical_features=cat_cols,)
x,y = oversample.fit_resample(ctrain.drop('target', axis=1), ctrain.target)

# %%
y.value_counts()
# Out:
# 10%     5811
# free    5811
# 50%     5811
# Name: target, dtype: int64

# %% [markdown]
# <h2 align=right style="line-height:200%;font-family:vazir;color:#0099cc">
# <font face="vazir" color="#0099cc">
# مدل‌سازی
# </font>
# </h2>
#
# <p dir=rtl style="direction: rtl; text-align: justify; line-height:200%; font-family:vazir; font-size:medium">
# <font face="vazir" size=3>
#     حال که داده را پاکسازی کرده و احتمالا ویژگی‌هایی را به آن افزوده یا از آن حذف کرده‌اید، وقت آن است که مدلی آموزش دهید که بتواند متغیر هدف این مسئله را پیش‌بینی کند.
# </font>
# </p>

# %%
target_col = 'target'

x_train,x_val , y_train,y_val = train_test_split(x, y, test_size=.1,\
                                                   random_state=535)

# %%
target2idx = {
    "free" : 0, 
    "10%" : 1,
    "50%" : 2
}

y_train = y_train.map(target2idx)
y_val = y_val.map(target2idx)

# %%
from xgboost import XGBClassifier

model = XGBClassifier()

model.fit(x_train, y_train)
# Out:
# XGBClassifier(base_score=0.5, booster='gbtree', callbacks=None,
#               colsample_bylevel=1, colsample_bynode=1, colsample_bytree=1,
#               early_stopping_rounds=None, enable_categorical=False,
#               eval_metric=None, feature_types=None, gamma=0, gpu_id=-1,
#               grow_policy='depthwise', importance_type=None,
#               interaction_constraints='', learning_rate=0.300000012,
#               max_bin=256, max_cat_threshold=64, max_cat_to_onehot=4,
#               max_delta_step=0, max_depth=6, max_leaves=0, min_child_weight=1,
#               missing=nan, monotone_constraints='()', n_estimators=100,
#               n_jobs=0, num_parallel_tree=1, objective='multi:softprob',
#               predictor='auto', ...)

# %% [markdown]
# <h3 align=right style="line-height:200%;font-family:vazir;color:#0099cc">
# <font face="vazir" color="#0099cc">
# معیار ارزیابی
# </font>
# </h3>
#
# <p dir=rtl style="direction: rtl; text-align: justify; line-height:200%; font-family:vazir; font-size:medium">
# <font face="vazir" size=3>
#     معیاری که برای ارزیابی عملکرد مدل انتخاب کرده‌ایم، <code>f1_score</code> نام دارد.
#     <br>
#     پیشنهاد می‌شود با توجه به این معیار، عملکرد مدل خود را بر روی مجموعه داده آموزش یا اعتبارسنجی ارزیابی کنید.
# </font>
# </p>

# %%
# evaluate model
import seaborn as sns

from sklearn.metrics import classification_report, confusion_matrix

y_pred = model.predict(x_val)
print(classification_report(y_val, y_pred))

sns.heatmap(confusion_matrix(y_pred, y_val), annot=True)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.83      0.83      0.83       578
#            1       0.85      0.83      0.84       578
#            2       0.96      0.98      0.97       588
#
#     accuracy                           0.88      1744
#    macro avg       0.88      0.88      0.88      1744
# weighted avg       0.88      0.88      0.88      1744
# <AxesSubplot: >

# %% [markdown]
# # Using Flaml

# %%
from flaml import AutoML

model = AutoML(task='classification', time_budget=60, metric='micro_f1', log_file_name = 'mylog.log')

model.fit(x_train, y_train)
# Out:
# [flaml.automl: 02-09 18:36:41] {2599} INFO - task = classification
# [flaml.automl: 02-09 18:36:41] {2601} INFO - Data split method: stratified
# [flaml.automl: 02-09 18:36:41] {2604} INFO - Evaluation method: holdout
# [flaml.automl: 02-09 18:36:41] {2726} INFO - Minimizing error metric: 1-micro_f1
# [flaml.automl: 02-09 18:36:41] {2870} INFO - List of ML learners in AutoML Run: ['lgbm', 'rf', 'xgboost', 'extra_tree', 'xgb_limitdepth', 'lrl1']
# [flaml.automl: 02-09 18:36:41] {3166} INFO - iteration 0, current learner lgbm
# [flaml.automl: 02-09 18:36:41] {3296} INFO - Estimated sufficient time budget=880s. Estimated necessary time budget=20s.
# [flaml.automl: 02-09 18:36:41] {3343} INFO -  at 0.2s,	estimator lgbm's best error=0.3817,	best estimator lgbm's best error=0.3817
# [flaml.automl: 02-09 18:36:41] {3166} INFO - iteration 1, current learner lgbm
# [flaml.automl: 02-09 18:36:41] {3343} INFO -  at 0.3s,	estimator lgbm's best error=0.3817,	best estimator lgbm's best error=0.3817
# [flaml.automl: 02-09 18:36:41] {3166} INFO - iteration 2, current learner lgbm
# [flaml.automl: 02-09 18:36:41] {3343} INFO -  at 0.4s,	estimator lgbm's best error=0.3779,	best estimator lgbm's best error=0.3779
# [flaml.automl: 02-09 18:36:41] {3166} INFO - iteration 3, current learner lgbm
# [flaml.automl: 02-09 18:36:41] {3343} INFO -  at 0.4s,	estimator lgbm's best error=0.2716,	best estimator lgbm's best error=0.2716
# [flaml.automl: 02-09 18:36:41] {3166} INFO - iteration 4, current learner lgbm
# [flaml.automl: 02-09 18:36:41] {3343} INFO -  at 0.5s,	estimator lgbm's best error=0.2716,	best estimator lgbm's best error=0.2716
# [flaml.automl: 02-09 18:36:41] {3166} INFO - iteration 5, current learner lgbm
# [flaml.automl: 02-09 18:36:41] {3343} INFO -  at 0.6s,	estimator lgbm's best error=0.2430,	best estimator lgbm's best error=0.2430
# [flaml.automl: 02-09 18:36:41] {3166} INFO - iteration 6, current learner xgboost
# [flaml.automl: 02-09 18:36:41] {3343} INFO -  at 0.7s,	estimator xgboost's best error=0.3817,	best estimator lgbm's best error=0.2430
# [flaml.automl: 02-09 18:36:41] {3166} INFO - iteration 7, current learner lgbm
# [flaml.automl: 02-09 18:36:41] {3343} INFO -  at 0.8s,	estimator lgbm's best error=0.2430,	best estimator lgbm's best error=0.2430
# [flaml.automl: 02-09 18:36:41] {3166} INFO - iteration 8, current learner lgbm
# [flaml.automl: 02-09 18:36:41] {3343} INFO -  at 0.9s,	estimator lgbm's best error=0.2430,	best estimator lgbm's best error=0.2430
# [flaml.automl: 02-09 18:36:41] {3166} INFO - iteration 9, current learner xgboost
# [flaml.automl: 02-09 18:36:42] {3343} INFO -  at 0.9s,	estimator xgboost's best error=0.3817,	best estimator lgbm's best error=0.2430
# [flaml.automl: 02-09 18:36:42] {3166} INFO - iteration 10, current learner xgboost
# [flaml.automl: 02-09 18:36:42] {3343} INFO -  at 1.0s,	estimator xgboost's best error=0.3817,	best estimator lgbm's best error=0.2430
# [flaml.automl: 02-09 18:36:42] {3166} INFO - iteration 11, current learner xgboost
# [flaml.automl: 02-09 18:36:42] {3343} INFO -  at 1.1s,	estimator xgboost's best error=0.3670,	best estimator lgbm's best error=0.2430
# [flaml.automl: 02-09 18:36:42] {3166} INFO - iteration 12, current learner extra_tree
# [flaml.automl: 02-09 18:36:42] {3343} INFO -  at 1.2s,	estimator extra_tree's best error=0.4726,	best estimator lgbm's best error=0.2430
# [flaml.automl: 02-09 18:36:42] {3166} INFO - iteration 13, current learner xgboost
# [flaml.automl: 02-09 18:36:42] {3343} INFO -  at 1.4s,	estimator xgboost's best error=0.3480,	best estimator lgbm's best error=0.2430
# [flaml.automl: 02-09 18:36:42] {3166} INFO - iteration 14, current learner extra_tree
# [flaml.automl: 02-09 18:36:42] {3343} INFO -  at 1.4s,	estimator extra_tree's best error=0.4205,	best estimator lgbm's best error=0.2430
# [flaml.automl: 02-09 18:36:42] {3166} INFO - iteration 15, current learner lgbm
# [flaml.automl: 02-09 18:36:42] {3343} INFO -  at 1.8s,	estimator lgbm's best error=0.2341,	best estimator lgbm's best error=0.2341
# [flaml.automl: 02-09 18:36:42] {3166} INFO - iteration 16, current learner rf
# [flaml.automl: 02-09 18:36:42] {3343} INFO -  at 1.9s,	estimator rf's best error=0.4288,	best estimator lgbm's best error=0.2341
# [flaml.automl: 02-09 18:36:42] {3166} INFO - iteration 17, current learner extra_tree
# [flaml.automl: 02-09 18:36:43] {3343} INFO -  at 2.0s,	estimator extra_tree's best error=0.4205,	best estimator lgbm's best error=0.2341
# [flaml.automl: 02-09 18:36:43] {3166} INFO - iteration 18, current learner lgbm
# [flaml.automl: 02-09 18:36:43] {3343} INFO -  at 2.2s,	estimator lgbm's best error=0.2341,	best estimator lgbm's best error=0.2341
# [flaml.automl: 02-09 18:36:43] {3166} INFO - iteration 19, current learner rf
# [flaml.automl: 02-09 18:36:43] {3343} INFO -  at 2.3s,	estimator rf's best error=0.3594,	best estimator lgbm's best error=0.2341
# [flaml.automl: 02-09 18:36:43] {3166} INFO - iteration 20, current learner rf
# [flaml.automl: 02-09 18:36:43] {3343} INFO -  at 2.4s,	estimator rf's best error=0.3594,	best estimator lgbm's best error=0.2341
# [flaml.automl: 02-09 18:36:43] {3166} INFO - iteration 21, current learner rf
# [flaml.automl: 02-09 18:36:43] {3343} INFO -  at 2.6s,	estimator rf's best error=0.3594,	best estimator lgbm's best error=0.2341
# [flaml.automl: 02-09 18:36:43] {3166} INFO - iteration 22, current learner lgbm
# [flaml.automl: 02-09 18:36:44] {3343} INFO -  at 3.5s,	estimator lgbm's best error=0.1234,	best estimator lgbm's best error=0.1234
# [flaml.automl: 02-09 18:36:44] {3166} INFO - iteration 23, current learner lgbm
# [flaml.automl: 02-09 18:36:45] {3343} INFO -  at 4.8s,	estimator lgbm's best error=0.1234,	best estimator lgbm's best error=0.1234
# [flaml.automl: 02-09 18:36:45] {3166} INFO - iteration 24, current learner extra_tree
# [flaml.automl: 02-09 18:36:45] {3343} INFO -  at 4.8s,	estimator extra_tree's best error=0.4205,	best estimator lgbm's best error=0.1234
# [flaml.automl: 02-09 18:36:45] {3166} INFO - iteration 25, current learner extra_tree
# [flaml.automl: 02-09 18:36:45] {3343} INFO -  at 4.9s,	estimator extra_tree's best error=0.4116,	best estimator lgbm's best error=0.1234
# [flaml.automl: 02-09 18:36:45] {3166} INFO - iteration 26, current learner lgbm
# [flaml.automl: 02-09 18:36:46] {3343} INFO -  at 5.7s,	estimator lgbm's best error=0.1234,	best estimator lgbm's best error=0.1234
# [flaml.automl: 02-09 18:36:46] {3166} INFO - iteration 27, current learner xgboost
# [flaml.automl: 02-09 18:36:46] {3343} INFO -  at 5.7s,	estimator xgboost's best error=0.3480,	best estimator lgbm's best error=0.1234
# [flaml.automl: 02-09 18:36:46] {3166} INFO - iteration 28, current learner xgboost
# [flaml.automl: 02-09 18:36:46] {3343} INFO -  at 5.8s,	estimator xgboost's best error=0.3257,	best estimator lgbm's best error=0.1234
# [flaml.automl: 02-09 18:36:46] {3166} INFO - iteration 29, current learner xgboost
# [flaml.automl: 02-09 18:36:47] {3343} INFO -  at 6.1s,	estimator xgboost's best error=0.2659,	best estimator lgbm's best error=0.1234
# [flaml.automl: 02-09 18:36:47] {3166} INFO - iteration 30, current learner lgbm
# [flaml.automl: 02-09 18:36:48] {3343} INFO -  at 7.0s,	estimator lgbm's best error=0.1234,	best estimator lgbm's best error=0.1234
# [flaml.automl: 02-09 18:36:48] {3166} INFO - iteration 31, current learner lgbm
# [flaml.automl: 02-09 18:36:49] {3343} INFO -  at 8.0s,	estimator lgbm's best error=0.1113,	best estimator lgbm's best error=0.1113
# [flaml.automl: 02-09 18:36:49] {3166} INFO - iteration 32, current learner lgbm
# [flaml.automl: 02-09 18:36:51] {3343} INFO -  at 10.0s,	estimator lgbm's best error=0.0916,	best estimator lgbm's best error=0.0916
# [flaml.automl: 02-09 18:36:51] {3166} INFO - iteration 33, current learner xgboost
# [flaml.automl: 02-09 18:36:51] {3343} INFO -  at 10.1s,	estimator xgboost's best error=0.2659,	best estimator lgbm's best error=0.0916
# [flaml.automl: 02-09 18:36:51] {3166} INFO - iteration 34, current learner lgbm
# [flaml.automl: 02-09 18:36:52] {3343} INFO -  at 11.3s,	estimator lgbm's best error=0.0916,	best estimator lgbm's best error=0.0916
# [flaml.automl: 02-09 18:36:52] {3166} INFO - iteration 35, current learner rf
# [flaml.automl: 02-09 18:36:52] {3343} INFO -  at 11.4s,	estimator rf's best error=0.3594,	best estimator lgbm's best error=0.0916
# [flaml.automl: 02-09 18:36:52] {3166} INFO - iteration 36, current learner xgboost
# [flaml.automl: 02-09 18:36:52] {3343} INFO -  at 11.6s,	estimator xgboost's best error=0.1800,	best estimator lgbm's best error=0.0916
# [flaml.automl: 02-09 18:36:52] {3166} INFO - iteration 37, current learner xgboost
# [flaml.automl: 02-09 18:36:52] {3343} INFO -  at 11.8s,	estimator xgboost's best error=0.1800,	best estimator lgbm's best error=0.0916
# [flaml.automl: 02-09 18:36:52] {3166} INFO - iteration 38, current learner xgboost
# [flaml.automl: 02-09 18:36:53] {3343} INFO -  at 12.1s,	estimator xgboost's best error=0.1800,	best estimator lgbm's best error=0.0916
# [flaml.automl: 02-09 18:36:53] {3166} INFO - iteration 39, current learner lgbm
# [flaml.automl: 02-09 18:36:56] {3343} INFO -  at 15.6s,	estimator lgbm's best error=0.0916,	best estimator lgbm's best error=0.0916
# [flaml.automl: 02-09 18:36:56] {3166} INFO - iteration 40, current learner xgboost
# [flaml.automl: 02-09 18:36:56] {3343} INFO -  at 15.9s,	estimator xgboost's best error=0.1571,	best estimator lgbm's best error=0.0916
# [flaml.automl: 02-09 18:36:56] {3166} INFO - iteration 41, current learner xgboost
# [flaml.automl: 02-09 18:36:57] {3343} INFO -  at 16.0s,	estimator xgboost's best error=0.1419,	best estimator lgbm's best error=0.0916
# [flaml.automl: 02-09 18:36:57] {3166} INFO - iteration 42, current learner lgbm
# [flaml.automl: 02-09 18:36:58] {3343} INFO -  at 17.0s,	estimator lgbm's best error=0.0916,	best estimator lgbm's best error=0.0916
# [flaml.automl: 02-09 18:36:58] {3166} INFO - iteration 43, current learner xgboost
# [flaml.automl: 02-09 18:36:58] {3343} INFO -  at 17.5s,	estimator xgboost's best error=0.1419,	best estimator lgbm's best error=0.0916
# [flaml.automl: 02-09 18:36:58] {3166} INFO - iteration 44, current learner extra_tree
# [flaml.automl: 02-09 18:36:58] {3343} INFO -  at 17.6s,	estimator extra_tree's best error=0.4116,	best estimator lgbm's best error=0.0916
# [flaml.automl: 02-09 18:36:58] {3166} INFO - iteration 45, current learner xgboost
# [flaml.automl: 02-09 18:36:58] {3343} INFO -  at 17.7s,	estimator xgboost's best error=0.1419,	best estimator lgbm's best error=0.0916
# [flaml.automl: 02-09 18:36:58] {3166} INFO - iteration 46, current learner rf
# [flaml.automl: 02-09 18:36:58] {3343} INFO -  at 17.8s,	estimator rf's best error=0.3594,	best estimator lgbm's best error=0.0916
# [flaml.automl: 02-09 18:36:58] {3166} INFO - iteration 47, current learner xgboost
# [flaml.automl: 02-09 18:36:59] {3343} INFO -  at 18.1s,	estimator xgboost's best error=0.1145,	best estimator lgbm's best error=0.0916
# [flaml.automl: 02-09 18:36:59] {3166} INFO - iteration 48, current learner lgbm
# [flaml.automl: 02-09 18:36:59] {3343} INFO -  at 18.6s,	estimator lgbm's best error=0.0916,	best estimator lgbm's best error=0.0916
# [flaml.automl: 02-09 18:36:59] {3166} INFO - iteration 49, current learner xgboost
# [flaml.automl: 02-09 18:36:59] {3343} INFO -  at 18.8s,	estimator xgboost's best error=0.1145,	best estimator lgbm's best error=0.0916
# [flaml.automl: 02-09 18:36:59] {3166} INFO - iteration 50, current learner xgboost
# [flaml.automl: 02-09 18:37:00] {3343} INFO -  at 19.6s,	estimator xgboost's best error=0.1145,	best estimator lgbm's best error=0.0916
# [flaml.automl: 02-09 18:37:00] {3166} INFO - iteration 51, current learner rf
# [flaml.automl: 02-09 18:37:00] {3343} INFO -  at 19.6s,	estimator rf's best error=0.3594,	best estimator lgbm's best error=0.0916
# [flaml.automl: 02-09 18:37:00] {3166} INFO - iteration 52, current learner rf
# [flaml.automl: 02-09 18:37:00] {3343} INFO -  at 19.8s,	estimator rf's best error=0.3238,	best estimator lgbm's best error=0.0916
# [flaml.automl: 02-09 18:37:00] {3166} INFO - iteration 53, current learner lgbm
# [flaml.automl: 02-09 18:37:07] {3343} INFO -  at 26.4s,	estimator lgbm's best error=0.0916,	best estimator lgbm's best error=0.0916
# [flaml.automl: 02-09 18:37:07] {3166} INFO - iteration 54, current learner lgbm
# [flaml.automl: 02-09 18:37:09] {3343} INFO -  at 28.2s,	estimator lgbm's best error=0.0916,	best estimator lgbm's best error=0.0916
# [flaml.automl: 02-09 18:37:09] {3166} INFO - iteration 55, current learner xgboost
# [flaml.automl: 02-09 18:37:09] {3343} INFO -  at 28.3s,	estimator xgboost's best error=0.1145,	best estimator lgbm's best error=0.0916
# [flaml.automl: 02-09 18:37:09] {3166} INFO - iteration 56, current learner rf
# [flaml.automl: 02-09 18:37:09] {3343} INFO -  at 28.4s,	estimator rf's best error=0.3238,	best estimator lgbm's best error=0.0916
# [flaml.automl: 02-09 18:37:09] {3166} INFO - iteration 57, current learner rf
# [flaml.automl: 02-09 18:37:09] {3343} INFO -  at 28.5s,	estimator rf's best error=0.3238,	best estimator lgbm's best error=0.0916
# [flaml.automl: 02-09 18:37:09] {3166} INFO - iteration 58, current learner xgboost
# [flaml.automl: 02-09 18:37:10] {3343} INFO -  at 29.6s,	estimator xgboost's best error=0.1031,	best estimator lgbm's best error=0.0916
# [flaml.automl: 02-09 18:37:10] {3166} INFO - iteration 59, current learner lgbm
# [flaml.automl: 02-09 18:37:12] {3343} INFO -  at 31.0s,	estimator lgbm's best error=0.0916,	best estimator lgbm's best error=0.0916
# [flaml.automl: 02-09 18:37:12] {3166} INFO - iteration 60, current learner xgboost
# [flaml.automl: 02-09 18:37:12] {3343} INFO -  at 31.8s,	estimator xgboost's best error=0.1031,	best estimator lgbm's best error=0.0916
# [flaml.automl: 02-09 18:37:12] {3166} INFO - iteration 61, current learner xgb_limitdepth
# [flaml.automl: 02-09 18:37:13] {3343} INFO -  at 32.1s,	estimator xgb_limitdepth's best error=0.2048,	best estimator lgbm's best error=0.0916
# [flaml.automl: 02-09 18:37:13] {3166} INFO - iteration 62, current learner xgb_limitdepth
# [flaml.automl: 02-09 18:37:13] {3343} INFO -  at 32.3s,	estimator xgb_limitdepth's best error=0.2048,	best estimator lgbm's best error=0.0916
# [flaml.automl: 02-09 18:37:13] {3166} INFO - iteration 63, current learner xgb_limitdepth
# [flaml.automl: 02-09 18:37:13] {3343} INFO -  at 32.7s,	estimator xgb_limitdepth's best error=0.1559,	best estimator lgbm's best error=0.0916
# [flaml.automl: 02-09 18:37:13] {3166} INFO - iteration 64, current learner xgb_limitdepth
# [flaml.automl: 02-09 18:37:14] {3343} INFO -  at 32.9s,	estimator xgb_limitdepth's best error=0.1559,	best estimator lgbm's best error=0.0916
# [flaml.automl: 02-09 18:37:14] {3166} INFO - iteration 65, current learner rf
# [flaml.automl: 02-09 18:37:14] {3343} INFO -  at 33.1s,	estimator rf's best error=0.2551,	best estimator lgbm's best error=0.0916
# [flaml.automl: 02-09 18:37:14] {3166} INFO - iteration 66, current learner rf
# [flaml.automl: 02-09 18:37:14] {3343} INFO -  at 33.2s,	estimator rf's best error=0.2551,	best estimator lgbm's best error=0.0916
# [flaml.automl: 02-09 18:37:14] {3166} INFO - iteration 67, current learner xgb_limitdepth
# [flaml.automl: 02-09 18:37:14] {3343} INFO -  at 33.4s,	estimator xgb_limitdepth's best error=0.1559,	best estimator lgbm's best error=0.0916
# [flaml.automl: 02-09 18:37:14] {3166} INFO - iteration 68, current learner rf
# [flaml.automl: 02-09 18:37:14] {3343} INFO -  at 33.6s,	estimator rf's best error=0.2373,	best estimator lgbm's best error=0.0916
# [flaml.automl: 02-09 18:37:14] {3166} INFO - iteration 69, current learner lgbm
# [flaml.automl: 02-09 18:37:15] {3343} INFO -  at 34.7s,	estimator lgbm's best error=0.0916,	best estimator lgbm's best error=0.0916
# [flaml.automl: 02-09 18:37:15] {3166} INFO - iteration 70, current learner xgboost
# [flaml.automl: 02-09 18:37:17] {3343} INFO -  at 36.5s,	estimator xgboost's best error=0.1031,	best estimator lgbm's best error=0.0916
# [flaml.automl: 02-09 18:37:17] {3166} INFO - iteration 71, current learner xgb_limitdepth
# [flaml.automl: 02-09 18:37:17] {3343} INFO -  at 36.7s,	estimator xgb_limitdepth's best error=0.1559,	best estimator lgbm's best error=0.0916
# [flaml.automl: 02-09 18:37:17] {3166} INFO - iteration 72, current learner xgboost
# [flaml.automl: 02-09 18:37:19] {3343} INFO -  at 38.1s,	estimator xgboost's best error=0.1031,	best estimator lgbm's best error=0.0916
# [flaml.automl: 02-09 18:37:19] {3166} INFO - iteration 73, current learner xgb_limitdepth
# [flaml.automl: 02-09 18:37:20] {3343} INFO -  at 39.0s,	estimator xgb_limitdepth's best error=0.1209,	best estimator lgbm's best error=0.0916
# [flaml.automl: 02-09 18:37:20] {3166} INFO - iteration 74, current learner xgb_limitdepth
# [flaml.automl: 02-09 18:37:21] {3343} INFO -  at 40.1s,	estimator xgb_limitdepth's best error=0.1151,	best estimator lgbm's best error=0.0916
# [flaml.automl: 02-09 18:37:21] {3166} INFO - iteration 75, current learner xgb_limitdepth
# [flaml.automl: 02-09 18:37:22] {3343} INFO -  at 41.1s,	estimator xgb_limitdepth's best error=0.1151,	best estimator lgbm's best error=0.0916
# [flaml.automl: 02-09 18:37:22] {3166} INFO - iteration 76, current learner rf
# [flaml.automl: 02-09 18:37:22] {3343} INFO -  at 41.2s,	estimator rf's best error=0.2137,	best estimator lgbm's best error=0.0916
# [flaml.automl: 02-09 18:37:22] {3166} INFO - iteration 77, current learner rf
# [flaml.automl: 02-09 18:37:22] {3343} INFO -  at 41.4s,	estimator rf's best error=0.2137,	best estimator lgbm's best error=0.0916
# [flaml.automl: 02-09 18:37:22] {3166} INFO - iteration 78, current learner xgboost
# [flaml.automl: 02-09 18:37:23] {3343} INFO -  at 42.7s,	estimator xgboost's best error=0.1031,	best estimator lgbm's best error=0.0916
# [flaml.automl: 02-09 18:37:23] {3166} INFO - iteration 79, current learner rf
# [flaml.automl: 02-09 18:37:23] {3343} INFO -  at 42.9s,	estimator rf's best error=0.1800,	best estimator lgbm's best error=0.0916
# [flaml.automl: 02-09 18:37:23] {3166} INFO - iteration 80, current learner rf
# [flaml.automl: 02-09 18:37:24] {3343} INFO -  at 43.0s,	estimator rf's best error=0.1800,	best estimator lgbm's best error=0.0916
# [flaml.automl: 02-09 18:37:24] {3166} INFO - iteration 81, current learner xgb_limitdepth
# [flaml.automl: 02-09 18:37:25] {3343} INFO -  at 44.3s,	estimator xgb_limitdepth's best error=0.1145,	best estimator lgbm's best error=0.0916
# [flaml.automl: 02-09 18:37:25] {3166} INFO - iteration 82, current learner rf
# [flaml.automl: 02-09 18:37:25] {3343} INFO -  at 44.4s,	estimator rf's best error=0.1800,	best estimator lgbm's best error=0.0916
# [flaml.automl: 02-09 18:37:25] {3166} INFO - iteration 83, current learner rf
# [flaml.automl: 02-09 18:37:25] {3343} INFO -  at 44.6s,	estimator rf's best error=0.1635,	best estimator lgbm's best error=0.0916
# [flaml.automl: 02-09 18:37:25] {3166} INFO - iteration 84, current learner rf
# [flaml.automl: 02-09 18:37:26] {3343} INFO -  at 44.9s,	estimator rf's best error=0.1489,	best estimator lgbm's best error=0.0916
# [flaml.automl: 02-09 18:37:26] {3166} INFO - iteration 85, current learner xgboost
# [flaml.automl: 02-09 18:37:26] {3343} INFO -  at 45.2s,	estimator xgboost's best error=0.1031,	best estimator lgbm's best error=0.0916
# [flaml.automl: 02-09 18:37:26] {3166} INFO - iteration 86, current learner rf
# [flaml.automl: 02-09 18:37:26] {3343} INFO -  at 45.4s,	estimator rf's best error=0.1489,	best estimator lgbm's best error=0.0916
# [flaml.automl: 02-09 18:37:26] {3166} INFO - iteration 87, current learner xgboost
# [flaml.automl: 02-09 18:37:28] {3343} INFO -  at 47.2s,	estimator xgboost's best error=0.1031,	best estimator lgbm's best error=0.0916
# [flaml.automl: 02-09 18:37:28] {3166} INFO - iteration 88, current learner rf
# [flaml.automl: 02-09 18:37:28] {3343} INFO -  at 47.5s,	estimator rf's best error=0.1489,	best estimator lgbm's best error=0.0916
# [flaml.automl: 02-09 18:37:28] {3166} INFO - iteration 89, current learner rf
# [flaml.automl: 02-09 18:37:28] {3343} INFO -  at 47.7s,	estimator rf's best error=0.1374,	best estimator lgbm's best error=0.0916
# [flaml.automl: 02-09 18:37:28] {3166} INFO - iteration 90, current learner extra_tree
# [flaml.automl: 02-09 18:37:28] {3343} INFO -  at 47.8s,	estimator extra_tree's best error=0.3766,	best estimator lgbm's best error=0.0916
# [flaml.automl: 02-09 18:37:28] {3166} INFO - iteration 91, current learner xgboost
# [flaml.automl: 02-09 18:37:29] {3343} INFO -  at 48.5s,	estimator xgboost's best error=0.1031,	best estimator lgbm's best error=0.0916
# [flaml.automl: 02-09 18:37:29] {3166} INFO - iteration 92, current learner extra_tree
# [flaml.automl: 02-09 18:37:29] {3343} INFO -  at 48.7s,	estimator extra_tree's best error=0.3562,	best estimator lgbm's best error=0.0916
# [flaml.automl: 02-09 18:37:29] {3166} INFO - iteration 93, current learner extra_tree
# [flaml.automl: 02-09 18:37:29] {3343} INFO -  at 48.8s,	estimator extra_tree's best error=0.3562,	best estimator lgbm's best error=0.0916
# [flaml.automl: 02-09 18:37:29] {3166} INFO - iteration 94, current learner xgboost
# [flaml.automl: 02-09 18:37:30] {3343} INFO -  at 49.6s,	estimator xgboost's best error=0.1031,	best estimator lgbm's best error=0.0916
# [flaml.automl: 02-09 18:37:30] {3166} INFO - iteration 95, current learner lgbm
# [flaml.automl: 02-09 18:37:33] {3343} INFO -  at 52.8s,	estimator lgbm's best error=0.0916,	best estimator lgbm's best error=0.0916
# [flaml.automl: 02-09 18:37:33] {3166} INFO - iteration 96, current learner extra_tree
# [flaml.automl: 02-09 18:37:34] {3343} INFO -  at 53.0s,	estimator extra_tree's best error=0.3562,	best estimator lgbm's best error=0.0916
# [flaml.automl: 02-09 18:37:34] {3166} INFO - iteration 97, current learner rf
# [flaml.automl: 02-09 18:37:34] {3343} INFO -  at 53.6s,	estimator rf's best error=0.1374,	best estimator lgbm's best error=0.0916
# [flaml.automl: 02-09 18:37:34] {3166} INFO - iteration 98, current learner xgboost
# [flaml.automl: 02-09 18:37:35] {3343} INFO -  at 54.1s,	estimator xgboost's best error=0.1031,	best estimator lgbm's best error=0.0916
# [flaml.automl: 02-09 18:37:35] {3166} INFO - iteration 99, current learner rf
# [flaml.automl: 02-09 18:37:35] {3343} INFO -  at 54.5s,	estimator rf's best error=0.1374,	best estimator lgbm's best error=0.0916
# [flaml.automl: 02-09 18:37:35] {3166} INFO - iteration 100, current learner rf
# [flaml.automl: 02-09 18:37:35] {3343} INFO -  at 54.8s,	estimator rf's best error=0.1374,	best estimator lgbm's best error=0.0916
# [flaml.automl: 02-09 18:37:35] {3166} INFO - iteration 101, current learner extra_tree
# [flaml.automl: 02-09 18:37:35] {3343} INFO -  at 54.9s,	estimator extra_tree's best error=0.2748,	best estimator lgbm's best error=0.0916
# [flaml.automl: 02-09 18:37:35] {3166} INFO - iteration 102, current learner extra_tree
# [flaml.automl: 02-09 18:37:36] {3343} INFO -  at 55.0s,	estimator extra_tree's best error=0.2748,	best estimator lgbm's best error=0.0916
# [flaml.automl: 02-09 18:37:36] {3166} INFO - iteration 103, current learner lgbm
# [flaml.automl: 02-09 18:37:41] {3343} INFO -  at 60.7s,	estimator lgbm's best error=0.0846,	best estimator lgbm's best error=0.0846
# [flaml.automl: 02-09 18:37:52] {3602} INFO - retrain lgbm for 10.8s
# [flaml.automl: 02-09 18:37:52] {3609} INFO - retrained model: LGBMClassifier(colsample_bytree=0.6289251564969597,
#                learning_rate=0.2294331192586551, max_bin=255,
#                min_child_samples=2, n_estimators=50, num_leaves=1210,
#                reg_alpha=0.0016090842157300092,
#                reg_lambda=0.0016514843937123268, verbose=-1)
# [flaml.automl: 02-09 18:37:52] {2901} INFO - fit succeeded
# [flaml.automl: 02-09 18:37:52] {2902} INFO - Time taken to find the best model: 60.73123002052307
# [flaml.automl: 02-09 18:37:52] {2913} WARNING - Time taken to find the best model is 101% of the provided time budget and not all estimators' hyperparameter search converged. Consider increasing the time budget.

# %%
# evaluate model
y_pred = model.predict(x_val)
print(classification_report(y_val, y_pred))

sns.heatmap(confusion_matrix(y_pred, y_val), annot=True)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.87      0.87      0.87       578
#            1       0.88      0.87      0.87       578
#            2       0.99      0.98      0.99       588
#
#     accuracy                           0.91      1744
#    macro avg       0.91      0.91      0.91      1744
# weighted avg       0.91      0.91      0.91      1744
# <AxesSubplot: >
